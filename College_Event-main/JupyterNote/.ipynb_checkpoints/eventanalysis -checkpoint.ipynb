# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("Event_Data.csv")

# %%
df.head(50)
# Out:
#     Event_ID            Event_Name Organizer Name  \
# 0          1   Criminal Crew Dance       CRIMINAL
# 1          2         SI Crew Dance             SI
# 2          3               Paryash            TTA
# 3          4  Team Culture Affairs             SI
# 4          5                 Umang           ZEAL
# 5          6         SI Crew Dance            TCA
# 6          7                  BGMI            TTA
# 7          8         SI Crew Dance       CRIMINAL
# 8          9   Criminal Crew Dance             SI
# 9         10  Team Culture Affairs       CRIMINAL
# 10        11                  Zeal            TCA
# 11        12                 Umang            TCA
# 12        13              Techniti           ZEAL
# 13        14               Paryash             SI
# 14        15               Utkansh       CRIMINAL
# 15        16  Team Culture Affairs             SI
# 16        17         SI Crew Dance       CRIMINAL
# 17        18  Team Culture Affairs            TCA
# 18        19               Paryash            TCA
# 19        20               Paryash            TCA
# 20        21               Paryash          ECELL
# 21        22   Criminal Crew Dance           ZEAL
# 22        23   Criminal Crew Dance          ECELL
# 23        24               Utkansh       CRIMINAL
# 24        25               Paryash           ZEAL
# 25        26  Team Culture Affairs            TCA
# 26        27                 Umang            TTA
# 27        28  Team Culture Affairs          ECELL
# 28        29                  Zeal            TCA
# 29        30               Utkansh          ECELL
# 30        31         SI Crew Dance            TCA
# 31        32                 Umang           ZEAL
# 32        33   Criminal Crew Dance             SI
# 33        34                 Umang            TTA
# 34        35                  Zeal             SI
# 35        36                  BGMI       CRIMINAL
# 36        37   Criminal Crew Dance            TCA
# 37        38                 Umang            TCA
# 38        39  Team Culture Affairs          ECELL
# 39        40              Techniti             SI
# 40        41         SI Crew Dance             SI
# 41        42         SI Crew Dance       CRIMINAL
# 42        43              Techniti            TCA
# 43        44         SI Crew Dance             SI
# 44        45         SI Crew Dance            TTA
# 45        46               Utkansh            TCA
# 46        47               Utkansh            TCA
# 47        48               Utkansh       CRIMINAL
# 48        49  Team Culture Affairs            TCA
# 49        50                 Umang          ECELL
#
#                                           Description           Venue  \
# 0   Lorem ipsum dolor sit amet, consectetuer adipi...     Main Ground
# 1   Vestibulum ac est lacinia nisi venenatis trist...    ECE Building
# 2   Fusce consequat. Nulla nisl. Nunc nisl.\n\nDui...      MBH Ground
# 3   Pellentesque at nulla. Suspendisse potenti. Cr...             CSH
# 4   Sed sagittis. Nam congue, risus semper porta v...     IT Building
# 5   In hac habitasse platea dictumst. Morbi vestib...  Cricket Ground
# 6   In hac habitasse platea dictumst. Morbi vestib...             OAT
# 7   Proin interdum mauris non ligula pellentesque ...      MBH Ground
# 8   Nullam porttitor lacus at turpis. Donec posuer...       BH Ground
# 9   Aenean lectus. Pellentesque eget nunc. Donec q...             OAT
# 10  Phasellus sit amet erat. Nulla tempus. Vivamus...     Main Ground
# 11  Nullam sit amet turpis elementum ligula vehicu...         Snacker
# 12  Vestibulum quam sapien, varius ut, blandit non...     Main Ground
# 13  Duis aliquam convallis nunc. Proin at turpis a...     Main Ground
# 14  Duis bibendum. Morbi non quam nec dui luctus r...      MBH Ground
# 15  Donec diam neque, vestibulum eget, vulputate u...  Cricket Ground
# 16  Cum sociis natoque penatibus et magnis dis par...     Main Ground
# 17  Fusce posuere felis sed lacus. Morbi sem mauri...      MBH Ground
# 18  Praesent id massa id nisl venenatis lacinia. A...     Main Ground
# 19  Praesent id massa id nisl venenatis lacinia. A...     IT Building
# 20  Cras mi pede, malesuada in, imperdiet et, comm...  Cricket Ground
# 21  Fusce consequat. Nulla nisl. Nunc nisl.\n\nDui...     IT Building
# 22  Morbi non lectus. Aliquam sit amet diam in mag...             OAT
# 23  Aenean lectus. Pellentesque eget nunc. Donec q...       BH Ground
# 24  Lorem ipsum dolor sit amet, consectetuer adipi...      MBH Ground
# 25  Cras mi pede, malesuada in, imperdiet et, comm...             CSH
# 26  Integer ac leo. Pellentesque ultrices mattis o...             OAT
# 27  Mauris enim leo, rhoncus sed, vestibulum sit a...    ECE Building
# 28  Duis consequat dui nec nisi volutpat eleifend....             OAT
# 29  Aenean fermentum. Donec ut mauris eget massa t...    ECE Building
# 30  Nam ultrices, libero non mattis pulvinar, null...     Main Ground
# 31  Quisque id justo sit amet sapien dignissim ves...     Main Ground
# 32  Proin leo odio, porttitor id, consequat in, co...     Main Ground
# 33  Aenean fermentum. Donec ut mauris eget massa t...     Main Ground
# 34  Quisque id justo sit amet sapien dignissim ves...  Cricket Ground
# 35  Fusce posuere felis sed lacus. Morbi sem mauri...     IT Building
# 36  Donec diam neque, vestibulum eget, vulputate u...     Main Ground
# 37  Proin eu mi. Nulla ac enim. In tempor, turpis ...       BH Ground
# 38  Duis bibendum. Morbi non quam nec dui luctus r...             CSH
# 39  In hac habitasse platea dictumst. Etiam faucib...         Snacker
# 40  Vestibulum ac est lacinia nisi venenatis trist...       BH Ground
# 41  Sed ante. Vivamus tortor. Duis mattis egestas ...     Main Ground
# 42  Praesent blandit. Nam nulla. Integer pede just...       BH Ground
# 43  Phasellus in felis. Donec semper sapien a libe...       BH Ground
# 44  Duis bibendum, felis sed interdum venenatis, t...       BH Ground
# 45  Sed sagittis. Nam congue, risus semper porta v...             CSH
# 46  Integer ac leo. Pellentesque ultrices mattis o...    ECE Building
# 47  Morbi porttitor lorem id ligula. Suspendisse o...    ECE Building
# 48  Nullam sit amet turpis elementum ligula vehicu...  Cricket Ground
# 49  Phasellus in felis. Donec semper sapien a libe...         Snacker
#
#           Date      Time  Attendance  Feedback_Score
# 0     8/2/2022   9:12 PM         606               5
# 1     3/8/2022   8:26 PM         353               2
# 2   11/30/2022   6:33 PM         362               5
# 3    5/17/2022   7:15 PM         511               5
# 4    7/19/2023  11:00 AM         590               4
# 5    8/28/2022   2:26 PM         325               4
# 6     3/7/2022   9:48 PM         259               5
# 7    10/7/2023   9:00 PM         246               2
# 8    4/26/2022   1:04 PM         429               3
# 9   10/30/2022   9:27 AM         563               2
# 10    6/9/2023  10:32 PM         802               4
# 11   2/23/2022  11:10 PM         539               4
# 12   5/22/2022   9:09 AM         423               3
# 13   6/24/2023  10:28 PM         612               2
# 14   10/1/2023   3:14 PM         913               5
# 15   8/12/2023  11:09 PM         704               2
# 16   1/31/2023   2:15 PM         811               3
# 17   10/8/2023  10:17 PM         382               2
# 18   5/12/2022  10:45 AM         330               5
# 19   4/15/2022   9:12 PM         972               5
# 20  10/27/2023   3:37 PM         806               5
# 21    1/9/2023   7:00 PM         301               4
# 22  12/19/2023   7:38 PM         824               5
# 23  12/19/2023   1:59 PM         792               2
# 24   9/23/2022  12:39 PM         554               5
# 25    7/3/2022   7:10 PM         457               4
# 26   4/27/2023   2:13 PM         944               3
# 27    9/9/2023   4:46 PM         495               2
# 28   5/19/2022   7:17 PM         282               2
# 29   3/28/2022   2:47 PM         286               4
# 30   2/24/2022   8:54 PM         522               2
# 31    7/6/2022  11:16 PM         441               4
# 32   9/23/2023   4:36 PM         943               3
# 33   9/30/2022   7:17 PM         805               3
# 34  11/23/2023   4:27 PM         384               4
# 35   3/22/2023   1:27 PM         218               4
# 36   5/29/2022  10:01 PM         764               5
# 37   8/10/2022  12:53 PM         425               4
# 38  10/19/2022   1:00 PM         461               4
# 39   4/11/2023   5:56 PM         329               4
# 40   7/30/2022   9:24 PM         880               4
# 41   8/28/2023   3:30 PM         813               2
# 42  10/17/2022  10:38 AM         991               5
# 43  10/21/2022  11:33 AM         974               5
# 44    7/1/2023   9:14 PM         980               4
# 45   9/24/2022  10:43 AM         811               2
# 46   1/30/2023  10:09 PM         871               4
# 47  11/10/2022   1:43 PM         966               3
# 48   7/22/2022  11:48 AM         335               5
# 49  12/24/2023   3:30 PM         540               2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Event_ID        1000 non-null   int64
#  1   Event_Name      1000 non-null   object
#  2   Organizer Name  1000 non-null   object
#  3   Description     1000 non-null   object
#  4   Venue           1000 non-null   object
#  5   Date            1000 non-null   object
#  6   Time            1000 non-null   object
#  7   Attendance      1000 non-null   int64
#  8   Feedback_Score  1000 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 70.4+ KB

# %%
df_tmp=df.copy()

# %%
df_tmp.head()
# Out:
#    Event_ID            Event_Name Organizer Name  \
# 0         1   Criminal Crew Dance       CRIMINAL
# 1         2         SI Crew Dance             SI
# 2         3               Paryash            TTA
# 3         4  Team Culture Affairs             SI
# 4         5                 Umang           ZEAL
#
#                                          Description         Venue  \
# 0  Lorem ipsum dolor sit amet, consectetuer adipi...   Main Ground
# 1  Vestibulum ac est lacinia nisi venenatis trist...  ECE Building
# 2  Fusce consequat. Nulla nisl. Nunc nisl.\n\nDui...    MBH Ground
# 3  Pellentesque at nulla. Suspendisse potenti. Cr...           CSH
# 4  Sed sagittis. Nam congue, risus semper porta v...   IT Building
#
#          Date      Time  Attendance  Feedback_Score
# 0    8/2/2022   9:12 PM         606               5
# 1    3/8/2022   8:26 PM         353               2
# 2  11/30/2022   6:33 PM         362               5
# 3   5/17/2022   7:15 PM         511               5
# 4   7/19/2023  11:00 AM         590               4

# %%
print(df_tmp['Date'].dtype)
# Out:
# object

# %%
df_tmp['Date'] = pd.to_datetime(df_tmp['Date'])

# %%
# Add datetime parameters for Eventdate
df_tmp["EventYear"] = df_tmp.Date.dt.year
df_tmp["EventMonth"] = df_tmp.Date.dt.month
df_tmp["EventDay"] = df_tmp.Date.dt.day

# %%
# Check for missing categories and different datatypes
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Event_ID        1000 non-null   int64
#  1   Event_Name      1000 non-null   object
#  2   Organizer Name  1000 non-null   object
#  3   Description     1000 non-null   object
#  4   Venue           1000 non-null   object
#  5   Date            1000 non-null   datetime64[ns]
#  6   Time            1000 non-null   object
#  7   Attendance      1000 non-null   int64
#  8   Feedback_Score  1000 non-null   int64
#  9   EventYear       1000 non-null   int64
#  10  EventMonth      1000 non-null   int64
#  11  EventDay        1000 non-null   int64
# dtypes: datetime64[ns](1), int64(6), object(5)
# memory usage: 93.9+ KB

# %%
# Check for missing values
df_tmp.isna().sum()
# Out:
# Event_ID          0
# Event_Name        0
# Organizer Name    0
# Description       0
# Venue             0
# Date              0
# Time              0
# Attendance        0
# Feedback_Score    0
# EventYear         0
# EventMonth        0
# EventDay          0
# dtype: int64

# %%
import pandas as pd
# This will turn all of the string values into category values
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        df_tmp[label] = content.astype("category").cat.as_ordered()

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Event_ID        1000 non-null   int64
#  1   Event_Name      1000 non-null   category
#  2   Organizer Name  1000 non-null   category
#  3   Description     1000 non-null   category
#  4   Venue           1000 non-null   category
#  5   Date            1000 non-null   datetime64[ns]
#  6   Time            1000 non-null   category
#  7   Attendance      1000 non-null   int64
#  8   Feedback_Score  1000 non-null   int64
#  9   EventYear       1000 non-null   int64
#  10  EventMonth      1000 non-null   int64
#  11  EventDay        1000 non-null   int64
# dtypes: category(5), datetime64[ns](1), int64(6)
# memory usage: 88.6 KB

# %%
df_tmp.isnull().sum()/len(df_tmp)
# Out:
# Event_ID          0.0
# Event_Name        0.0
# Organizer Name    0.0
# Description       0.0
# Venue             0.0
# Date              0.0
# Time              0.0
# Attendance        0.0
# Feedback_Score    0.0
# EventYear         0.0
# EventMonth        0.0
# EventDay          0.0
# dtype: float64

# %%
# From above obseravation we see there is no missing data

# %%
df_tmp.sort_values(by=["EventYear","EventMonth","EventDay"], inplace=True, ascending=True)

# Save preprocessed data
df_tmp.to_csv("train_tmp.csv",
              index=False)

# %%
# Import preprocessed data
df_tmp = pd.read_csv("train_tmp.csv",
                     low_memory=False)
df_tmp.head()
# Out:
#    Event_ID            Event_Name Organizer Name  \
# 0       211   Criminal Crew Dance           ZEAL
# 1        12                 Umang            TCA
# 2       403  Team Culture Affairs            TTA
# 3       482               Paryash            TTA
# 4        31         SI Crew Dance            TCA
#
#                                          Description        Venue        Date  \
# 0  Maecenas ut massa quis augue luctus tincidunt....  IT Building  2022-02-20
# 1  Nullam sit amet turpis elementum ligula vehicu...      Snacker  2022-02-23
# 2  Vestibulum quam sapien, varius ut, blandit non...    BH Ground  2022-02-23
# 3  Vestibulum quam sapien, varius ut, blandit non...  IT Building  2022-02-23
# 4  Nam ultrices, libero non mattis pulvinar, null...  Main Ground  2022-02-24
#
#        Time  Attendance  Feedback_Score  EventYear  EventMonth  EventDay
# 0  11:12 AM         395               5       2022           2        20
# 1  11:10 PM         539               4       2022           2        23
# 2  11:01 AM         232               3       2022           2        23
# 3  11:23 AM         761               3       2022           2        23
# 4   8:54 PM         522               2       2022           2        24

# %% [markdown]
# ### Turn categorical variables into numbers
# for label, content in df_tmp.items():
#     # Check columns which *aren't* numeric
#     if not pd.api.types.is_numeric_dtype(content):
#         # We add the +1 because pandas encodes missing categories as -1
#         df_tmp[label] = pd.Categorical(content).codes+1

# %%
for label, content in df_tmp.items(): 
    # Check columns which aren't numeric
    if not pd.api.types.is_numeric_dtype(content): 
        # We add the +1 because pandas encodes missing categories as -1 
        df_tmp[label] = pd.Categorical(content).codes+1

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Event_ID        1000 non-null   int64
#  1   Event_Name      1000 non-null   int8
#  2   Organizer Name  1000 non-null   int8
#  3   Description     1000 non-null   int16
#  4   Venue           1000 non-null   int8
#  5   Date            1000 non-null   int16
#  6   Time            1000 non-null   int16
#  7   Attendance      1000 non-null   int64
#  8   Feedback_Score  1000 non-null   int64
#  9   EventYear       1000 non-null   int64
#  10  EventMonth      1000 non-null   int64
#  11  EventDay        1000 non-null   int64
# dtypes: int16(3), int64(6), int8(3)
# memory usage: 55.8 KB

# %%
df_tmp.isna().sum()
# Out:
# Event_ID          0
# Event_Name        0
# Organizer Name    0
# Description       0
# Venue             0
# Date              0
# Time              0
# Attendance        0
# Feedback_Score    0
# EventYear         0
# EventMonth        0
# EventDay          0
# dtype: int64

# %%
# Everything except target variable
X = df_tmp.drop("Feedback_Score", axis=1)

# Target variable
y = df_tmp.Feedback_Score.values

# %%
# Random seed for reproducibility
import numpy as np
np.random.seed(42)

# Split into train & test set
X_train, X_test, y_train, y_test = train_test_split(X, # independent variables 
                                                    y, # dependent variable
                                                    test_size = 0.2) # percentage of data to use for test set

# %%
# %%time
# Instantiate model
model = RandomForestRegressor(n_jobs=-1)


# Fit the model
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
# Out:
# CPU times: total: 172 ms
# Wall time: 264 ms

# %%
## Models
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

## Model evaluators
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# E.g. using past events to try and predict future events.

# Knowing this, randomly splitting our data into train and test sets using something like train_test_split() wouldn't work.

# Instead, we split our data into training, validation and test sets using the date each sample occured.

# In our case:

#   Training = all samples up until 2023 march
#    Valid = all samples form April 1, 2023 - may 30, 2023
#    Test = all samples from june 1, 2023 - Januray 2024

# %%
# Random seed for reproducibility
np.random.seed(42)

# Split into train & test set
X_train, X_test, y_train, y_test = train_test_split(X, # independent variables 
                                                    y, # dependent variable
                                                    test_size = 0.2) # percentage of data to use for test set

# %%
models = {"KNN": KNeighborsClassifier(),
          "Logistic Regression": LogisticRegression(), 
          "Random Forest": RandomForestClassifier()}

# Create function to fit and score models
def fit_and_score(models, X_train, X_test, y_train, y_test):
    """
    Fits and evaluates given machine learning models.
    models : a dict of different Scikit-Learn machine learning models
    X_train : training data
    X_test : testing data
    y_train : labels assosciated with training data
    y_test : labels assosciated with test data
    """
    # Random seed for reproducible results
    np.random.seed(42)
    # Make a list to keep model scores
    model_scores = {}
    # Loop through models
    for name, model in models.items():
        # Fit the model to the data
        model.fit(X_train, y_train)
        # Evaluate the model and append its score to model_scores
        model_scores[name] = model.score(X_test, y_test)
    return model_scores

# %%
model_scores = fit_and_score(models=models,
                             X_train=X_train,
                             X_test=X_test,
                             y_train=y_train,
                             y_test=y_test)
model_scores
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# {'KNN': 0.275, 'Logistic Regression': 0.225, 'Random Forest': 0.295}

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.265

# %%
y_pred
# Out:
# array([5, 3, 3, 2, 5, 5, 2, 3, 5, 3, 4, 3, 4, 2, 2, 3, 3, 5, 3, 3, 4, 4,
#        2, 3, 3, 3, 3, 4, 3, 2, 5, 4, 2, 2, 2, 3, 3, 4, 3, 5, 5, 3, 5, 2,
#        2, 5, 5, 5, 3, 5, 3, 3, 2, 2, 3, 3, 3, 4, 4, 5, 5, 4, 4, 4, 3, 3,
#        3, 2, 5, 3, 3, 4, 3, 5, 3, 3, 3, 2, 4, 5, 4, 4, 2, 3, 3, 3, 3, 4,
#        5, 2, 3, 3, 4, 2, 3, 5, 4, 3, 5, 3, 3, 5, 2, 4, 2, 4, 2, 2, 4, 5,
#        5, 3, 4, 3, 4, 5, 3, 4, 3, 3, 3, 3, 2, 5, 4, 3, 4, 3, 4, 3, 5, 5,
#        5, 5, 5, 5, 5, 4, 2, 2, 5, 4, 5, 5, 5, 4, 5, 3, 3, 4, 3, 3, 4, 2,
#        5, 5, 5, 3, 3, 3, 2, 4, 4, 2, 3, 5, 5, 2, 3, 2, 4, 4, 5, 3, 2, 5,
#        3, 3, 2, 3, 3, 5, 2, 3, 3, 2, 4, 2, 3, 3, 5, 3, 4, 3, 5, 5, 2, 3,
#        3, 5], dtype=int64)

# %%
# Create a list of train scores
train_scores = []

# Create a list of test scores
test_scores = []

# Create a list of different values for n_neighbors
neighbors = range(1, 21) # 1 to 20

# Setup algorithm
knn = KNeighborsClassifier()

# Loop through different neighbors values
for i in neighbors:
    knn.set_params(n_neighbors = i) # set neighbors value
    
    # Fit the algorithm
    knn.fit(X_train, y_train)
    
    # Update the training scores
    train_scores.append(knn.score(X_train, y_train))
    
    # Update the test scores
    test_scores.append(knn.score(X_test, y_test))

# %%
import matplotlib.pyplot as plt
plt.plot(neighbors, train_scores, label="Train score")
plt.plot(neighbors, test_scores, label="Test score")
plt.xticks(np.arange(1, 21, 1))
plt.xlabel("Number of neighbors")
plt.ylabel("Model score")
plt.legend()

print(f"Maximum KNN score on the test data: {max(test_scores)*100:.2f}%")
# Out:
# Maximum KNN score on the test data: 31.00%

# %%
# Initialize KNN classifier with best n_neighbors
best_knn = KNeighborsClassifier(n_neighbors=1)

# Fit the model to the training data
best_knn.fit(X_train, y_train)

# Make predictions on new data (e.g., X_test)
y_pred = best_knn.predict(X_test)

# %%
y_pred
# Out:
# array([4, 2, 2, 2, 5, 5, 2, 5, 2, 3, 2, 2, 3, 2, 4, 5, 5, 2, 2, 5, 2, 2,
#        4, 2, 3, 4, 3, 4, 5, 2, 2, 4, 5, 3, 3, 3, 3, 4, 2, 3, 5, 5, 2, 2,
#        4, 4, 3, 3, 5, 4, 3, 4, 2, 3, 3, 5, 2, 4, 4, 5, 5, 3, 5, 5, 5, 3,
#        3, 5, 2, 4, 2, 2, 3, 4, 3, 5, 2, 5, 4, 3, 4, 5, 2, 5, 5, 3, 2, 4,
#        5, 3, 3, 5, 4, 2, 3, 5, 4, 3, 4, 5, 3, 5, 5, 4, 5, 2, 5, 3, 3, 2,
#        5, 2, 3, 3, 5, 3, 3, 4, 2, 3, 3, 2, 2, 5, 3, 5, 3, 4, 5, 5, 5, 5,
#        5, 2, 3, 5, 3, 4, 4, 4, 2, 3, 2, 5, 5, 2, 5, 5, 3, 4, 2, 2, 4, 5,
#        2, 4, 3, 2, 4, 2, 3, 4, 5, 5, 2, 5, 4, 5, 5, 4, 4, 4, 5, 4, 5, 4,
#        2, 2, 4, 4, 5, 3, 3, 3, 3, 3, 5, 4, 2, 3, 5, 2, 4, 5, 3, 5, 2, 3,
#        4, 5], dtype=int64)

# %%
from joblib import dump

# %%
dump(model,'./../savedModels/model.joblib')
